# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}
# Out:
# tar: \DriverData: Couldn't visit directory: No such file or directory
# tar: Error exit delayed from previous errors.

# %%
df = pd.read_csv(r"C:\Users\palla\OneDrive\Documents\demo_data\7.xor.csv",header=None)

# %%
df.head()
# Out:
#           0         1    2
# 0  1.764052  0.400157 -1.0
# 1  0.978738  2.240893 -1.0
# 2  1.867558 -0.977278  1.0
# 3  0.950088 -0.151357  1.0
# 4 -0.103219  0.410599  1.0

# %%
df.shape
# Out:
# (500, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       500 non-null    float64
#  1   1       500 non-null    float64
#  2   2       500 non-null    float64
# dtypes: float64(3)
# memory usage: 11.8 KB

# %%
sns.scatterplot(x=0,y=1,hue=2,data=df)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %% [markdown]
# ## split into train and test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[[0,1]],df[2],test_size=0.1)

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_train_trans = std.fit_transform(X_train)
X_test_trans = std.transform(X_test)

# %% [markdown]
# ## build the neural networks

# %%
model = Sequential()
model.add(Dense(15,activation='relu',input_dim=2))

model.add(Dense(7,activation='relu'))

model.add(Dense(3,activation='sigmoid'))

model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                45
#
#  dense_1 (Dense)             (None, 7)                 112
#
#  dense_2 (Dense)             (None, 3)                 24
#
#  dense_3 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 185
# Trainable params: 185
# Non-trainable params: 0
# _________________________________________________________________

# %%
# complie model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,batch_size=10,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# C:\Users\palla\anaconda3\lib\site-packages\keras\engine\data_adapter.py:1700: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 36/36 [==============================] - 1s 9ms/step - loss: 0.4879 - accuracy: 0.0000e+00 - val_loss: 0.4573 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.4256 - accuracy: 0.0000e+00 - val_loss: 0.3952 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3678 - accuracy: 0.0000e+00 - val_loss: 0.3366 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3108 - accuracy: 0.0000e+00 - val_loss: 0.2837 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2568 - accuracy: 0.0000e+00 - val_loss: 0.2305 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2067 - accuracy: 0.0000e+00 - val_loss: 0.1829 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.1605 - accuracy: 0.0000e+00 - val_loss: 0.1442 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.1211 - accuracy: 0.0000e+00 - val_loss: 0.1029 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0815 - accuracy: 0.0000e+00 - val_loss: 0.0680 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.0000e+00 - val_loss: 0.0299 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: -0.0081 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.0222 - accuracy: 0.0000e+00 - val_loss: -0.0423 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.0553 - accuracy: 0.0000e+00 - val_loss: -0.0771 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.0878 - accuracy: 0.0000e+00 - val_loss: -0.1098 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.1214 - accuracy: 0.0000e+00 - val_loss: -0.1466 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.1585 - accuracy: 0.0000e+00 - val_loss: -0.1824 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.2000 - accuracy: 0.0000e+00 - val_loss: -0.2261 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.2488 - accuracy: 0.0000e+00 - val_loss: -0.2773 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.3001 - accuracy: 0.0000e+00 - val_loss: -0.3304 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.3546 - accuracy: 0.0000e+00 - val_loss: -0.3806 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.4063 - accuracy: 0.0000e+00 - val_loss: -0.4344 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.4566 - accuracy: 0.0000e+00 - val_loss: -0.4834 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 36/36 [==============================] - 0s 3ms/step - loss: -0.5067 - accuracy: 0.0000e+00 - val_loss: -0.5389 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.5566 - accuracy: 0.0250 - val_loss: -0.5887 - val_accuracy: 0.0333
# Epoch 25/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.6079 - accuracy: 0.0611 - val_loss: -0.6413 - val_accuracy: 0.0889
# Epoch 26/100
# 36/36 [==============================] - 0s 5ms/step - loss: -0.6586 - accuracy: 0.0861 - val_loss: -0.6977 - val_accuracy: 0.1333
# Epoch 27/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.7117 - accuracy: 0.1083 - val_loss: -0.7495 - val_accuracy: 0.1667
# Epoch 28/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.7618 - accuracy: 0.1639 - val_loss: -0.7996 - val_accuracy: 0.1889
# Epoch 29/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.8144 - accuracy: 0.2167 - val_loss: -0.8496 - val_accuracy: 0.2444
# Epoch 30/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.8685 - accuracy: 0.2306 - val_loss: -0.9058 - val_accuracy: 0.2667
# Epoch 31/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.9215 - accuracy: 0.2611 - val_loss: -0.9557 - val_accuracy: 0.2889
# Epoch 32/100
# 36/36 [==============================] - 0s 4ms/step - loss: -0.9721 - accuracy: 0.2750 - val_loss: -1.0070 - val_accuracy: 0.2889
# Epoch 33/100
# 36/36 [==============================] - 0s 4ms/step - loss: -1.0197 - accuracy: 0.2972 - val_loss: -1.0523 - val_accuracy: 0.2889
# Epoch 34/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.0728 - accuracy: 0.3000 - val_loss: -1.1093 - val_accuracy: 0.3000
# Epoch 35/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.1215 - accuracy: 0.3139 - val_loss: -1.1626 - val_accuracy: 0.3333
# Epoch 36/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.1693 - accuracy: 0.3333 - val_loss: -1.2045 - val_accuracy: 0.3444
# Epoch 37/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.2162 - accuracy: 0.3417 - val_loss: -1.2474 - val_accuracy: 0.3333
# Epoch 38/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.2619 - accuracy: 0.3389 - val_loss: -1.2943 - val_accuracy: 0.3333
# Epoch 39/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.3104 - accuracy: 0.3472 - val_loss: -1.3478 - val_accuracy: 0.3444
# Epoch 40/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.3540 - accuracy: 0.3556 - val_loss: -1.3903 - val_accuracy: 0.3444
# Epoch 41/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.3984 - accuracy: 0.3611 - val_loss: -1.4286 - val_accuracy: 0.3556
# Epoch 42/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.4434 - accuracy: 0.3639 - val_loss: -1.4736 - val_accuracy: 0.4000
# Epoch 43/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.4857 - accuracy: 0.3722 - val_loss: -1.5150 - val_accuracy: 0.3889
# Epoch 44/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.5315 - accuracy: 0.3750 - val_loss: -1.5667 - val_accuracy: 0.4000
# Epoch 45/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.5738 - accuracy: 0.3750 - val_loss: -1.6043 - val_accuracy: 0.4000
# Epoch 46/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.6151 - accuracy: 0.3778 - val_loss: -1.6478 - val_accuracy: 0.4000
# Epoch 47/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.6570 - accuracy: 0.3861 - val_loss: -1.6874 - val_accuracy: 0.4000
# Epoch 48/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.6983 - accuracy: 0.3889 - val_loss: -1.7295 - val_accuracy: 0.4000
# Epoch 49/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.7360 - accuracy: 0.3861 - val_loss: -1.7709 - val_accuracy: 0.4111
# Epoch 50/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.7814 - accuracy: 0.3917 - val_loss: -1.8097 - val_accuracy: 0.4111
# Epoch 51/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.8239 - accuracy: 0.3917 - val_loss: -1.8524 - val_accuracy: 0.4111
# Epoch 52/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.8605 - accuracy: 0.3917 - val_loss: -1.8871 - val_accuracy: 0.4111
# Epoch 53/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.9009 - accuracy: 0.3917 - val_loss: -1.9326 - val_accuracy: 0.4111
# Epoch 54/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.9429 - accuracy: 0.3972 - val_loss: -1.9742 - val_accuracy: 0.4111
# Epoch 55/100
# 36/36 [==============================] - 0s 4ms/step - loss: -1.9844 - accuracy: 0.3944 - val_loss: -2.0094 - val_accuracy: 0.4111
# Epoch 56/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.0203 - accuracy: 0.4000 - val_loss: -2.0558 - val_accuracy: 0.4111
# Epoch 57/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.0631 - accuracy: 0.3972 - val_loss: -2.0947 - val_accuracy: 0.4111
# Epoch 58/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.0997 - accuracy: 0.4000 - val_loss: -2.1310 - val_accuracy: 0.4111
# Epoch 59/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.1393 - accuracy: 0.4083 - val_loss: -2.1701 - val_accuracy: 0.4111
# Epoch 60/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.1785 - accuracy: 0.4111 - val_loss: -2.2085 - val_accuracy: 0.4111
# Epoch 61/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.2169 - accuracy: 0.4028 - val_loss: -2.2451 - val_accuracy: 0.4111
# Epoch 62/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.2569 - accuracy: 0.4167 - val_loss: -2.2909 - val_accuracy: 0.4111
# Epoch 63/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.2958 - accuracy: 0.4028 - val_loss: -2.3319 - val_accuracy: 0.4333
# Epoch 64/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.3332 - accuracy: 0.4194 - val_loss: -2.3662 - val_accuracy: 0.4111
# Epoch 65/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.3738 - accuracy: 0.4028 - val_loss: -2.3964 - val_accuracy: 0.4111
# Epoch 66/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.4126 - accuracy: 0.4139 - val_loss: -2.4405 - val_accuracy: 0.4333
# Epoch 67/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.4489 - accuracy: 0.4167 - val_loss: -2.4769 - val_accuracy: 0.4111
# Epoch 68/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.4842 - accuracy: 0.4111 - val_loss: -2.5192 - val_accuracy: 0.4111
# Epoch 69/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.5252 - accuracy: 0.4111 - val_loss: -2.5588 - val_accuracy: 0.4333
# Epoch 70/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.5641 - accuracy: 0.4139 - val_loss: -2.5924 - val_accuracy: 0.4333
# Epoch 71/100
# 36/36 [==============================] - 0s 5ms/step - loss: -2.6019 - accuracy: 0.4139 - val_loss: -2.6307 - val_accuracy: 0.4333
# Epoch 72/100
# 36/36 [==============================] - 0s 5ms/step - loss: -2.6411 - accuracy: 0.4167 - val_loss: -2.6711 - val_accuracy: 0.4333
# Epoch 73/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.6769 - accuracy: 0.4167 - val_loss: -2.7115 - val_accuracy: 0.4333
# Epoch 74/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.7159 - accuracy: 0.4139 - val_loss: -2.7448 - val_accuracy: 0.4333
# Epoch 75/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.7517 - accuracy: 0.4167 - val_loss: -2.7827 - val_accuracy: 0.4333
# Epoch 76/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.7940 - accuracy: 0.4167 - val_loss: -2.8195 - val_accuracy: 0.4333
# Epoch 77/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.8263 - accuracy: 0.4111 - val_loss: -2.8590 - val_accuracy: 0.4333
# Epoch 78/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.8686 - accuracy: 0.4111 - val_loss: -2.8938 - val_accuracy: 0.4444
# Epoch 79/100
# 36/36 [==============================] - 0s 5ms/step - loss: -2.9052 - accuracy: 0.4194 - val_loss: -2.9315 - val_accuracy: 0.4333
# Epoch 80/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.9449 - accuracy: 0.4167 - val_loss: -2.9718 - val_accuracy: 0.4444
# Epoch 81/100
# 36/36 [==============================] - 0s 4ms/step - loss: -2.9780 - accuracy: 0.4167 - val_loss: -3.0050 - val_accuracy: 0.4333
# Epoch 82/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.0186 - accuracy: 0.4194 - val_loss: -3.0407 - val_accuracy: 0.4333
# Epoch 83/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.0559 - accuracy: 0.4139 - val_loss: -3.0856 - val_accuracy: 0.4444
# Epoch 84/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.0913 - accuracy: 0.4139 - val_loss: -3.1151 - val_accuracy: 0.4444
# Epoch 85/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.1316 - accuracy: 0.4167 - val_loss: -3.1622 - val_accuracy: 0.4333
# Epoch 86/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.1678 - accuracy: 0.4167 - val_loss: -3.1930 - val_accuracy: 0.4333
# Epoch 87/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.2025 - accuracy: 0.4167 - val_loss: -3.2343 - val_accuracy: 0.4556
# Epoch 88/100
# 36/36 [==============================] - 0s 3ms/step - loss: -3.2402 - accuracy: 0.4139 - val_loss: -3.2741 - val_accuracy: 0.4333
# Epoch 89/100
# 36/36 [==============================] - 0s 5ms/step - loss: -3.2844 - accuracy: 0.4194 - val_loss: -3.3043 - val_accuracy: 0.4333
# Epoch 90/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.3129 - accuracy: 0.4167 - val_loss: -3.3373 - val_accuracy: 0.4556
# Epoch 91/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.3554 - accuracy: 0.4222 - val_loss: -3.3817 - val_accuracy: 0.4556
# Epoch 92/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.3917 - accuracy: 0.4194 - val_loss: -3.4195 - val_accuracy: 0.4556
# Epoch 93/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.4233 - accuracy: 0.4167 - val_loss: -3.4643 - val_accuracy: 0.4556
# Epoch 94/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.4662 - accuracy: 0.4250 - val_loss: -3.4916 - val_accuracy: 0.4333
# Epoch 95/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.5052 - accuracy: 0.4111 - val_loss: -3.5206 - val_accuracy: 0.4556
# Epoch 96/100
# 36/36 [==============================] - 0s 4ms/step - loss: -3.5386 - accuracy: 0.4222 - val_loss: -3.5552 - val_accuracy: 0.4333
# Epoch 97/100
# 36/36 [==============================] - 0s 3ms/step - loss: -3.5833 - accuracy: 0.4222 - val_loss: -3.6054 - val_accuracy: 0.4556
# Epoch 98/100
# 36/36 [==============================] - 0s 3ms/step - loss: -3.6122 - accuracy: 0.4167 - val_loss: -3.6439 - val_accuracy: 0.4556
# Epoch 99/100
# 36/36 [==============================] - 0s 3ms/step - loss: -3.6507 - accuracy: 0.4278 - val_loss: -3.6836 - val_accuracy: 0.4556
# Epoch 100/100
# 36/36 [==============================] - 0s 3ms/step - loss: -3.6916 - accuracy: 0.4222 - val_loss: -3.7149 - val_accuracy: 0.4556

# %%
y_cap= model.predict(X_test_trans)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
y_cap_f = np.where(y_cap>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_cap_f)
# Out:
# 0.48

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(df[[0,1]].values,df[2].values.astype(int),clf=model)
# Out:
# 3888/3888 [==============================] - 7s 2ms/step
# <AxesSubplot:>

# %%
plot_decision_regions(X_test_trans,y_test.values.astype(int),clf=model)
# Out:
# 3888/3888 [==============================] - 5s 1ms/step
# <AxesSubplot:>
